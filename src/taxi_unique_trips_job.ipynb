# %% [markdown]
# # Taxi Unique Trips Job
#
# This notebook creates a view of unique taxi trips by date.

# %%
# Get parameters from job widgets
dbutils.widgets.text("catalog", "")
dbutils.widgets.text("schema", "")
dbutils.widgets.text("view_name", "taxi_unique_trips")

catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
view_name = dbutils.widgets.get("view_name")

# %%
# Set the default catalog and schema
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")

# %%
# Import the taxis module from the doan_dabs_test package
from doan_dabs_test import taxis

# Create the view with the specified name
created_view = taxis.create_taxi_unique_trips_view(view_name)

print(f"Created {created_view} view")

# %%
# Show a sample of the results
print(f"Sample data from {created_view}:")
spark.sql(f"SELECT * FROM {created_view} LIMIT 10").show()

# Output the view name for downstream tasks
print(f"VIEW_NAME={created_view}")
